# %%
import os
import gc
import json
import math
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa
IS_INTERACTIVE = os.environ['KAGGLE_KERNEL_RUN_TYPE'] == 'Interactive'
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
with open ("/kaggle/input/asl-fingerspelling/character_to_prediction_index.json", "r") as f:
    char_to_num = json.load(f)

pad_token = '^'
pad_token_idx = 59

char_to_num[pad_token] = pad_token_idx

num_to_char = {j:i for i,j in char_to_num.items()}
df = pd.read_csv('/kaggle/input/asl-fingerspelling/train.csv')

LIP = [
    61, 185, 40, 39, 37, 0, 267, 269, 270, 409,
    291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
    78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
    95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
]
LPOSE = [13, 15, 17, 19, 21]
RPOSE = [14, 16, 18, 20, 22]
POSE = LPOSE + RPOSE

X = [f'x_right_hand_{i}' for i in range(21)]  +[f'x_left_hand_{i}' for i in range(21)] + [f'x_pose_{i}' for i in POSE] + [f'x_face_{i}' for i in LIP] #+ 
Y = [f'y_right_hand_{i}' for i in range(21)]  +[f'y_left_hand_{i}' for i in range(21)]+ [f'y_pose_{i}' for i in POSE] + [f'y_face_{i}' for i in LIP] #+
Z = [f'z_right_hand_{i}' for i in range(21)]  + [f'z_left_hand_{i}' for i in range(21)]+ [f'z_pose_{i}' for i in POSE] + [f'z_face_{i}' for i in LIP] #+ 

SEL_COLS = X + Y + Z
FRAME_LEN = 128 + 48
MAX_PHRASE_LENGTH = 64

LIP_IDX_X   = [i for i, col in enumerate(SEL_COLS)  if  "face" in col and "x" in col]
RHAND_IDX_X = [i for i, col in enumerate(SEL_COLS)  if "right" in col and "x" in col]
LHAND_IDX_X = [i for i, col in enumerate(SEL_COLS)  if  "left" in col and "x" in col]
RPOSE_IDX_X = [i for i, col in enumerate(SEL_COLS)  if  "pose" in col and int(col[-2:]) in RPOSE and "x" in col]
LPOSE_IDX_X = [i for i, col in enumerate(SEL_COLS)  if  "pose" in col and int(col[-2:]) in LPOSE and "x" in col]

LIP_IDX_Y   = [i for i, col in enumerate(SEL_COLS)  if  "face" in col and "y" in col]
RHAND_IDX_Y = [i for i, col in enumerate(SEL_COLS)  if "right" in col and "y" in col]
LHAND_IDX_Y = [i for i, col in enumerate(SEL_COLS)  if  "left" in col and "y" in col]
RPOSE_IDX_Y = [i for i, col in enumerate(SEL_COLS)  if  "pose" in col and int(col[-2:]) in RPOSE and "y" in col]
LPOSE_IDX_Y = [i for i, col in enumerate(SEL_COLS)  if  "pose" in col and int(col[-2:]) in LPOSE and "y" in col]

LIP_IDX_Z   = [i for i, col in enumerate(SEL_COLS)  if  "face" in col and "z" in col]
RHAND_IDX_Z = [i for i, col in enumerate(SEL_COLS)  if "right" in col and "z" in col]
LHAND_IDX_Z = [i for i, col in enumerate(SEL_COLS)  if  "left" in col and "z" in col]
RPOSE_IDX_Z = [i for i, col in enumerate(SEL_COLS)  if  "pose" in col and int(col[-2:]) in RPOSE and "z" in col]
LPOSE_IDX_Z = [i for i, col in enumerate(SEL_COLS)  if  "pose" in col and int(col[-2:]) in LPOSE and "z" in col]

RHM = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/rh_mean.npy")
LHM = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/lh_mean.npy")
RPM = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/rp_mean.npy")
LPM = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/lp_mean.npy")
LIPM = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/lip_mean.npy")

RHS = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/rh_std.npy")
LHS = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/lh_std.npy")
RPS = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/rp_std.npy")
LPS = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/lp_std.npy")
LIPS = np.load("/kaggle/input/aslfr-dataset-tfrecords/mean_std/lip_std.npy")

# %%
def load_relevant_data_subset(pq_path):
    return pd.read_parquet(pq_path, columns=SEL_COLS)

file_id = df.file_id.iloc[0]
inpdir = "/kaggle/input/asl-fingerspelling/train_landmarks"
pqfile = f"{inpdir}/{file_id}.parquet"
seq_refs = df.loc[df.file_id == file_id]
seqs = load_relevant_data_subset(pqfile)

seq_id = seq_refs.sequence_id.iloc[0]
frames = seqs.iloc[seqs.index == seq_id]
phrase = str(df.loc[df.sequence_id == seq_id].phrase.iloc[0])

# %%
@tf.function()
def resize_pad(x):
    if tf.shape(x)[0] < FRAME_LEN:
        x = tf.pad(x, ([[0, FRAME_LEN-tf.shape(x)[0]], [0, 0], [0, 0]]), constant_values=float("NaN"))
    else:
        x = tf.image.resize(x, (FRAME_LEN, tf.shape(x)[1]))
    return x

#@tf.function(jit_compile=True)
def pre_process0(x):
    lip_x = tf.gather(x, LIP_IDX_X, axis=1)
    lip_y = tf.gather(x, LIP_IDX_Y, axis=1)
    lip_z = tf.gather(x, LIP_IDX_Z, axis=1)

    rhand_x = tf.gather(x, RHAND_IDX_X, axis=1)
    rhand_y = tf.gather(x, RHAND_IDX_Y, axis=1)
    rhand_z = tf.gather(x, RHAND_IDX_Z, axis=1)
    
    lhand_x = tf.gather(x, LHAND_IDX_X, axis=1)
    lhand_y = tf.gather(x, LHAND_IDX_Y, axis=1)
    lhand_z = tf.gather(x, LHAND_IDX_Z, axis=1)

    rpose_x = tf.gather(x, RPOSE_IDX_X, axis=1)
    rpose_y = tf.gather(x, RPOSE_IDX_Y, axis=1)
    rpose_z = tf.gather(x, RPOSE_IDX_Z, axis=1)
    
    lpose_x = tf.gather(x, LPOSE_IDX_X, axis=1)
    lpose_y = tf.gather(x, LPOSE_IDX_Y, axis=1)
    lpose_z = tf.gather(x, LPOSE_IDX_Z, axis=1)
    
    lip   = tf.concat([lip_x[..., tf.newaxis], lip_y[..., tf.newaxis], lip_z[..., tf.newaxis]], axis=-1)
    rhand = tf.concat([rhand_x[..., tf.newaxis], rhand_y[..., tf.newaxis], rhand_z[..., tf.newaxis]], axis=-1)
    lhand = tf.concat([lhand_x[..., tf.newaxis], lhand_y[..., tf.newaxis], lhand_z[..., tf.newaxis]], axis=-1)
    rpose = tf.concat([rpose_x[..., tf.newaxis], rpose_y[..., tf.newaxis], rpose_z[..., tf.newaxis]], axis=-1)
    lpose = tf.concat([lpose_x[..., tf.newaxis], lpose_y[..., tf.newaxis], lpose_z[..., tf.newaxis]], axis=-1)
        
    # TIME AUGMENTATION
    if tf.random.uniform(shape=(), minval=0, maxval=1)<0.2:
        new_width = tf.shape(lip)[1]
        new_height = tf.random.uniform(
            shape=(), minval = tf.cast(tf.shape(lip)[0],tf.float32) / 2.0, 
            maxval = tf.cast(tf.shape(lip)[0],tf.float32) * 1.5, dtype=tf.int32)
        resized_lip = tf.image.resize(lip, (new_height, new_width))
        resized_rhand = tf.image.resize(rhand, (new_height, new_width))
        resized_lhand = tf.image.resize(lhand, (new_height, new_width))
        resized_rpose = tf.image.resize(rpose, (new_height, new_width))
        resized_lpose = tf.image.resize(lpose, (new_height, new_width))
        return resized_lip, resized_rhand, resized_lhand, resized_rpose, resized_lpose        
        
    return lip, rhand, lhand,  rpose, lpose 

@tf.function(jit_compile=True)
def pre_process00(x):
    lip_x = tf.gather(x, LIP_IDX_X, axis=1)
    lip_y = tf.gather(x, LIP_IDX_Y, axis=1)
    lip_z = tf.gather(x, LIP_IDX_Z, axis=1)

    rhand_x = tf.gather(x, RHAND_IDX_X, axis=1)
    rhand_y = tf.gather(x, RHAND_IDX_Y, axis=1)
    rhand_z = tf.gather(x, RHAND_IDX_Z, axis=1)
    
    lhand_x = tf.gather(x, LHAND_IDX_X, axis=1)
    lhand_y = tf.gather(x, LHAND_IDX_Y, axis=1)
    lhand_z = tf.gather(x, LHAND_IDX_Z, axis=1)

    rpose_x = tf.gather(x, RPOSE_IDX_X, axis=1)
    rpose_y = tf.gather(x, RPOSE_IDX_Y, axis=1)
    rpose_z = tf.gather(x, RPOSE_IDX_Z, axis=1)
    
    lpose_x = tf.gather(x, LPOSE_IDX_X, axis=1)
    lpose_y = tf.gather(x, LPOSE_IDX_Y, axis=1)
    lpose_z = tf.gather(x, LPOSE_IDX_Z, axis=1)
    
    lip   = tf.concat([lip_x[..., tf.newaxis], lip_y[..., tf.newaxis], lip_z[..., tf.newaxis]], axis=-1)
    rhand = tf.concat([rhand_x[..., tf.newaxis], rhand_y[..., tf.newaxis], rhand_z[..., tf.newaxis]], axis=-1)
    lhand = tf.concat([lhand_x[..., tf.newaxis], lhand_y[..., tf.newaxis], lhand_z[..., tf.newaxis]], axis=-1)
    rpose = tf.concat([rpose_x[..., tf.newaxis], rpose_y[..., tf.newaxis], rpose_z[..., tf.newaxis]], axis=-1)
    lpose = tf.concat([lpose_x[..., tf.newaxis], lpose_y[..., tf.newaxis], lpose_z[..., tf.newaxis]], axis=-1)
                
    hand = tf.concat([rhand, lhand], axis=1)
    hand = tf.where(tf.math.is_nan(hand), 0.0, hand)
    input_tensor = tf.math.not_equal(tf.reduce_sum(hand, axis=[1, 2]), 0.0)
    alternating_tensor = tf.math.equal( tf.cumsum(tf.ones_like( tf.reduce_sum(hand, axis=[1, 2]) ))%2, 1.0 )
    mask = tf.math.logical_or(input_tensor, alternating_tensor)
    
    lip = lip[mask]
    rhand = rhand[mask]
    lhand = lhand[mask]
    rpose = rpose[mask]
    lpose = lpose[mask]

    return lip, rhand, lhand,  rpose, lpose

@tf.function()
def pre_process1(lip, rhand,lhand,  rpose, lpose): #lhand,
    lip   = (resize_pad(lip) - LIPM) / LIPS
    rhand = (resize_pad(rhand) - RHM) / RHS
    lhand = (resize_pad(lhand) - LHM) / LHS
    rpose = (resize_pad(rpose) - RPM) / RPS
    lpose = (resize_pad(lpose) - LPM) / LPS

    x = tf.concat([lip, rhand, lhand, rpose, lpose], axis=1) #lhand,
    s = tf.shape(x)
    x = tf.reshape(x, (s[0], s[1]*s[2]))
    x = tf.where(tf.math.is_nan(x), 0.0, x)
    return x

pre0 = pre_process0(frames)
pre1 = pre_process1(*pre0)
INPUT_SHAPE = list(pre1.shape)
print(INPUT_SHAPE)
# Out:
# [176, 276]

# %%
def decode_fn(record_bytes):
    schema = {
        "lip": tf.io.VarLenFeature(tf.float32),
        "rhand": tf.io.VarLenFeature(tf.float32),
        "lhand": tf.io.VarLenFeature(tf.float32),
        "rpose": tf.io.VarLenFeature(tf.float32),
        "lpose": tf.io.VarLenFeature(tf.float32),
        "phrase": tf.io.VarLenFeature(tf.int64)
    }
    x = tf.io.parse_single_example(record_bytes, schema)

    lip = tf.reshape(tf.sparse.to_dense(x["lip"]), (-1, 40, 3))
    rhand = tf.reshape(tf.sparse.to_dense(x["rhand"]), (-1, 21, 3))
    lhand = tf.reshape(tf.sparse.to_dense(x["lhand"]), (-1, 21, 3))
    rpose = tf.reshape(tf.sparse.to_dense(x["rpose"]), (-1, 5, 3))
    lpose = tf.reshape(tf.sparse.to_dense(x["lpose"]), (-1, 5, 3))
    phrase = tf.sparse.to_dense(x["phrase"])

    return lip, rhand, lhand,  rpose, lpose, phrase #lhand,

def pre_process_fn(lip, rhand,lhand,  rpose, lpose, phrase): #lhand,
    phrase = tf.pad(phrase, [[0, MAX_PHRASE_LENGTH-tf.shape(phrase)[0]]], constant_values=pad_token_idx)
    return pre_process1(lip, rhand, lhand, rpose, lpose), phrase #lhand,
    
tffiles = [f"/kaggle/input/chris-tf-v9/{file_id}.tfrecord" for file_id in df.file_id.unique()]
val_len = 1
train_batch_size = 128
val_batch_size = 128

train_dataset =  tf.data.TFRecordDataset(tffiles[val_len:]).prefetch(tf.data.AUTOTUNE).shuffle(5000).map(decode_fn, num_parallel_calls=tf.data.AUTOTUNE).map(pre_process_fn, num_parallel_calls=tf.data.AUTOTUNE).batch(train_batch_size).prefetch(tf.data.AUTOTUNE)
val_dataset =  tf.data.TFRecordDataset(tffiles[:val_len]).prefetch(tf.data.AUTOTUNE).map(decode_fn, num_parallel_calls=tf.data.AUTOTUNE).map(pre_process_fn, num_parallel_calls=tf.data.AUTOTUNE).batch(val_batch_size).prefetch(tf.data.AUTOTUNE)

batch = next(iter(val_dataset))
batch[0].shape, batch[1].shape
# Out:
# (TensorShape([128, 176, 276]), TensorShape([128, 64]))

# %%
class ECA(tf.keras.layers.Layer):
    def __init__(self, kernel_size=5, **kwargs):
        super().__init__(**kwargs)
        self.supports_masking = True
        self.kernel_size = kernel_size
        self.conv = tf.keras.layers.Conv1D(1, kernel_size=kernel_size, strides=1, padding="same", use_bias=False)

    def call(self, inputs, mask=None):
        nn = tf.keras.layers.GlobalAveragePooling1D()(inputs, mask=mask)
        nn = tf.expand_dims(nn, -1)
        nn = self.conv(nn)
        nn = tf.squeeze(nn, -1)
        nn = tf.nn.sigmoid(nn)
        nn = nn[:,None,:]
        return inputs * nn

class CausalDWConv1D(tf.keras.layers.Layer):
    def __init__(self, 
        kernel_size=17,
        dilation_rate=1,
        use_bias=False,
        depthwise_initializer='glorot_uniform',
        name='', **kwargs):
        super().__init__(name=name,**kwargs)
        self.causal_pad = tf.keras.layers.ZeroPadding1D((dilation_rate*(kernel_size-1),0),name=name + '_pad')
        self.dw_conv = tf.keras.layers.DepthwiseConv1D(
                            kernel_size,
                            strides=1,
                            dilation_rate=dilation_rate,
                            padding='valid',
                            use_bias=use_bias,
                            depthwise_initializer=depthwise_initializer,
                            name=name + '_dwconv')
        self.supports_masking = True
        
    def call(self, inputs):
        x = self.causal_pad(inputs)
        x = self.dw_conv(x)
        return x

def Conv1DBlock(channel_size,
          kernel_size,
          dilation_rate=1,
          drop_rate=0.0,
          expand_ratio=2,
          se_ratio=0.25,
          activation='swish',
          name=None):
    '''
    efficient conv1d block, @hoyso48
    '''
    if name is None:
        name = str(tf.keras.backend.get_uid("mbblock"))
    # Expansion phase
    def apply(inputs):
        channels_in = tf.keras.backend.int_shape(inputs)[-1]
        channels_expand = channels_in * expand_ratio

        skip = inputs

        x = tf.keras.layers.Dense(
            channels_expand,
            use_bias=True,
            activation=activation,
            name=name + '_expand_conv')(inputs)

        # Depthwise Convolution
        x = CausalDWConv1D(kernel_size,
            dilation_rate=dilation_rate,
            use_bias=False,
            name=name + '_dwconv')(x)

        x = tf.keras.layers.BatchNormalization(momentum=0.95, name=name + '_bn')(x)

        x  = ECA()(x)

        x = tf.keras.layers.Dense(
            channel_size,
            use_bias=True,
            name=name + '_project_conv')(x)

        if drop_rate > 0:
            x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1), name=name + '_drop')(x)

        if (channels_in == channel_size):
            x = tf.keras.layers.add([x, skip], name=name + '_add')
        return x

    return apply

class MultiHeadSelfAttention(tf.keras.layers.Layer):
    def __init__(self, dim=256, num_heads=4, dropout=0, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.scale = self.dim ** -0.5
        self.num_heads = num_heads
        self.qkv = tf.keras.layers.Dense(3 * dim, use_bias=False)
        self.drop1 = tf.keras.layers.Dropout(dropout)
        self.proj = tf.keras.layers.Dense(dim, use_bias=False)
        self.supports_masking = True

    def call(self, inputs, mask=None):
        qkv = self.qkv(inputs)
        qkv = tf.keras.layers.Permute((2, 1, 3))(tf.keras.layers.Reshape((-1, self.num_heads, self.dim * 3 // self.num_heads))(qkv))
        q, k, v = tf.split(qkv, [self.dim // self.num_heads] * 3, axis=-1)

        attn = tf.matmul(q, k, transpose_b=True) * self.scale

        if mask is not None:
            mask = mask[:, None, None, :]

        attn = tf.keras.layers.Softmax(axis=-1)(attn, mask=mask)
        attn = self.drop1(attn)

        x = attn @ v
        x = tf.keras.layers.Reshape((-1, self.dim))(tf.keras.layers.Permute((2, 1, 3))(x))
        x = self.proj(x)
        return x


def ConformerBlock(dim=256, num_heads=6, expand=4, attn_dropout=0.2, conv_kernel_size=17, conv_dilation_rate=1, ffn_dropout=0.2, activation='swish', drop_rate=0.2):
    '''
    Conformer block implementation with FeedForward, MHSA, Conv1DBlock, and Layer Normalization
    '''
    def apply(inputs):
        # First FeedForward Block
        x = inputs
        x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
        x = tf.keras.layers.Dense(dim * expand, activation=activation, use_bias=True)(x)

        # Multi-Head Self Attention
        x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
        x = MultiHeadSelfAttention(dim=dim, num_heads=num_heads, dropout=attn_dropout)(x)
        x = tf.keras.layers.Dropout(ffn_dropout)(x)
        x = tf.keras.layers.Add()([inputs, x])  # Residual connection

        # Convolution Layer using the custom Conv1DBlock
        x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
        x = Conv1DBlock(channel_size=dim, kernel_size=conv_kernel_size, dilation_rate=conv_dilation_rate, drop_rate=drop_rate, expand_ratio=4)(x)

        # Another FeedForward Block
        x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
        x = tf.keras.layers.Dense(dim, activation=activation, use_bias=True)(x)
        x = tf.keras.layers.Dropout(ffn_dropout)(x)

        # Final Residual Add
        x = tf.keras.layers.Add()([x, inputs])
        return x

    return apply

def positional_encoding(maxlen, num_hid):
        depth = num_hid/2
        positions = tf.range(maxlen, dtype = tf.float32)[..., tf.newaxis]
        depths = tf.range(depth, dtype = tf.float32)[np.newaxis, :]/depth
        angle_rates = tf.math.divide(1, tf.math.pow(tf.cast(10000, tf.float32), depths))
        angle_rads = tf.linalg.matmul(positions, angle_rates)
        pos_encoding = tf.concat(
          [tf.math.sin(angle_rads), tf.math.cos(angle_rads)],
          axis=-1)
        return pos_encoding

# %%
def CTCLoss(labels, logits):
    label_length = tf.reduce_sum(tf.cast(labels != pad_token_idx, tf.int32), axis=-1)
    logit_length = tf.ones(tf.shape(logits)[0], dtype=tf.int32) * tf.shape(logits)[1]
    loss = tf.nn.ctc_loss(
            labels=labels,
            logits=logits,
            label_length=label_length,
            logit_length=logit_length,
            blank_index=pad_token_idx,
            logits_time_major=False
        )
    loss = tf.reduce_mean(loss)
    return loss

# %%
# def get_model(dim = 384):
#     inp = tf.keras.Input(INPUT_SHAPE)
#     x = tf.keras.layers.Masking(mask_value=0.0)(inp)
#     x = tf.keras.layers.Dense(dim, use_bias=False, name='stem_conv')(x)
#     pe = tf.cast(positional_encoding(INPUT_SHAPE[0], dim), dtype=x.dtype)
#     x = x + pe
#     x = tf.keras.layers.BatchNormalization(momentum=0.95,name='stem_bn')(x)
#     num_blocks = 6
#     drop_rate  = 0.4
#     for i in range(num_blocks):
#         x = Conv1DBlock(dim, 11, drop_rate=drop_rate)(x)
#         x = Conv1DBlock(dim,  5, drop_rate=drop_rate)(x)
#         x = Conv1DBlock(dim,  3, drop_rate=drop_rate)(x)
#         x = TransformerBlock(dim, expand=2)(x)

#     x = tf.keras.layers.Dense(dim*2,activation='relu',name='top_conv')(x)
#     x = tf.keras.layers.Dropout(0.4)(x)
#     #x = LateDropout(0.7)(x)
#     x = tf.keras.layers.Dense(len(char_to_num),name='classifier')(x)

#     model = tf.keras.Model(inp, x)

#     loss = CTCLoss
    
#     # Adam Optimizer
#     optimizer = tfa.optimizers.RectifiedAdam(sma_threshold=4)
#     optimizer = tfa.optimizers.Lookahead(optimizer, sync_period=5)

#     model.compile(loss=loss, optimizer=optimizer)

#     return model

def get_model(dim=384, num_blocks=6, conv_kernel_size=17, conv_dilation_rate=1, ffn_dropout=0.2, drop_rate=0.2):
    inp = tf.keras.Input(INPUT_SHAPE)
    x = tf.keras.layers.Masking(mask_value=0.0)(inp)
    x = tf.keras.layers.Dense(dim, use_bias=False, name='stem_conv')(x)

    # Positional Encoding
    pe = tf.cast(positional_encoding(INPUT_SHAPE[0], dim), dtype=x.dtype)
    x = x + pe
    x = tf.keras.layers.BatchNormalization(momentum=0.95, name='stem_bn')(x)

    # Conformer blocks with Conv1D blocks before each Conformer block
    for i in range(num_blocks):
        # Dynamically create unique names for Conv1D blocks
        # conv_block1 = Conv1DBlock(channel_size=dim, kernel_size=conv_kernel_size, dilation_rate=conv_dilation_rate, drop_rate=drop_rate, expand_ratio=4, name=f'conv_block1_{i}')
        # conv_block2 = Conv1DBlock(channel_size=dim, kernel_size=conv_kernel_size, dilation_rate=conv_dilation_rate, drop_rate=drop_rate, expand_ratio=4, name=f'conv_block2_{i}')

        # Apply the Conv1D blocks
        # x = conv_block1(x)
        # x = conv_block2(x)

        # Apply the Conformer block
        x = ConformerBlock(dim, num_heads=6, expand=4)(x)

    # Final output layer
    x = tf.keras.layers.Dense(dim * 2, activation='relu', name='top_conv')(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.Dense(len(char_to_num), name='classifier')(x)

    model = tf.keras.Model(inp, x)

    # Define loss and optimizer
    loss = CTCLoss
    optimizer = tfa.optimizers.RectifiedAdam(sma_threshold=4)
    optimizer = tfa.optimizers.Lookahead(optimizer, sync_period=5)

    model.compile(loss=loss, optimizer=optimizer)

    return model

tf.keras.backend.clear_session()
model = get_model()
model(batch[0])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 176, 276)]   0           []
#
#  masking (Masking)              (None, 176, 276)     0           ['input_1[0][0]']
#
#  stem_conv (Dense)              (None, 176, 384)     105984      ['masking[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 176, 384)    0           ['stem_conv[0][0]']
#  da)
#
#  stem_bn (BatchNormalization)   (None, 176, 384)     1536        ['tf.__operators__.add[0][0]']
#
#  layer_normalization (LayerNorm  (None, 176, 384)    768         ['stem_bn[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 176, 1536)    591360      ['layer_normalization[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 176, 1536)   3072        ['dense[0][0]']
#  rmalization)
#
#  multi_head_self_attention (Mul  (None, 176, 384)    1916928     ['layer_normalization_1[0][0]']
#  tiHeadSelfAttention)
#
#  dropout_1 (Dropout)            (None, 176, 384)     0           ['multi_head_self_attention[0][0]
#                                                                  ']
#
#  add (Add)                      (None, 176, 384)     0           ['stem_bn[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 176, 384)    768         ['add[0][0]']
#  rmalization)
#
#  1_expand_conv (Dense)          (None, 176, 1536)    591360      ['layer_normalization_2[0][0]']
#
#  1_dwconv (CausalDWConv1D)      (None, 176, 1536)    26112       ['1_expand_conv[0][0]']
#
#  1_bn (BatchNormalization)      (None, 176, 1536)    6144        ['1_dwconv[0][0]']
#
#  eca (ECA)                      (None, 176, 1536)    5           ['1_bn[0][0]']
#
#  1_project_conv (Dense)         (None, 176, 384)     590208      ['eca[0][0]']
#
#  1_drop (Dropout)               (None, 176, 384)     0           ['1_project_conv[0][0]']
#
#  1_add (Add)                    (None, 176, 384)     0           ['1_drop[0][0]',
#                                                                   'layer_normalization_2[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 176, 384)    768         ['1_add[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 176, 384)     147840      ['layer_normalization_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 176, 384)     0           ['dense_3[0][0]']
#
#  add_1 (Add)                    (None, 176, 384)     0           ['dropout_2[0][0]',
#                                                                   'stem_bn[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 176, 384)    768         ['add_1[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 176, 1536)    591360      ['layer_normalization_4[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 176, 1536)   3072        ['dense_4[0][0]']
#  rmalization)
#
#  multi_head_self_attention_1 (M  (None, 176, 384)    1916928     ['layer_normalization_5[0][0]']
#  ultiHeadSelfAttention)
#
#  dropout_4 (Dropout)            (None, 176, 384)     0           ['multi_head_self_attention_1[0][
#                                                                  0]']
#
#  add_2 (Add)                    (None, 176, 384)     0           ['add_1[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 176, 384)    768         ['add_2[0][0]']
#  rmalization)
#
#  2_expand_conv (Dense)          (None, 176, 1536)    591360      ['layer_normalization_6[0][0]']
#
#  2_dwconv (CausalDWConv1D)      (None, 176, 1536)    26112       ['2_expand_conv[0][0]']
#
#  2_bn (BatchNormalization)      (None, 176, 1536)    6144        ['2_dwconv[0][0]']
#
#  eca_1 (ECA)                    (None, 176, 1536)    5           ['2_bn[0][0]']
#
#  2_project_conv (Dense)         (None, 176, 384)     590208      ['eca_1[0][0]']
#
#  2_drop (Dropout)               (None, 176, 384)     0           ['2_project_conv[0][0]']
#
#  2_add (Add)                    (None, 176, 384)     0           ['2_drop[0][0]',
#                                                                   'layer_normalization_6[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 176, 384)    768         ['2_add[0][0]']
#  rmalization)
#
#  dense_7 (Dense)                (None, 176, 384)     147840      ['layer_normalization_7[0][0]']
#
#  dropout_5 (Dropout)            (None, 176, 384)     0           ['dense_7[0][0]']
#
#  add_3 (Add)                    (None, 176, 384)     0           ['dropout_5[0][0]',
#                                                                   'add_1[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 176, 384)    768         ['add_3[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 176, 1536)    591360      ['layer_normalization_8[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 176, 1536)   3072        ['dense_8[0][0]']
#  rmalization)
#
#  multi_head_self_attention_2 (M  (None, 176, 384)    1916928     ['layer_normalization_9[0][0]']
#  ultiHeadSelfAttention)
#
#  dropout_7 (Dropout)            (None, 176, 384)     0           ['multi_head_self_attention_2[0][
#                                                                  0]']
#
#  add_4 (Add)                    (None, 176, 384)     0           ['add_3[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 176, 384)    768         ['add_4[0][0]']
#  ormalization)
#
#  3_expand_conv (Dense)          (None, 176, 1536)    591360      ['layer_normalization_10[0][0]']
#
#  3_dwconv (CausalDWConv1D)      (None, 176, 1536)    26112       ['3_expand_conv[0][0]']
#
#  3_bn (BatchNormalization)      (None, 176, 1536)    6144        ['3_dwconv[0][0]']
#
#  eca_2 (ECA)                    (None, 176, 1536)    5           ['3_bn[0][0]']
#
#  3_project_conv (Dense)         (None, 176, 384)     590208      ['eca_2[0][0]']
#
#  3_drop (Dropout)               (None, 176, 384)     0           ['3_project_conv[0][0]']
#
#  3_add (Add)                    (None, 176, 384)     0           ['3_drop[0][0]',
#                                                                   'layer_normalization_10[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 176, 384)    768         ['3_add[0][0]']
#  ormalization)
#
#  dense_11 (Dense)               (None, 176, 384)     147840      ['layer_normalization_11[0][0]']
#
#  dropout_8 (Dropout)            (None, 176, 384)     0           ['dense_11[0][0]']
#
#  add_5 (Add)                    (None, 176, 384)     0           ['dropout_8[0][0]',
#                                                                   'add_3[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 176, 384)    768         ['add_5[0][0]']
#  ormalization)
#
#  dense_12 (Dense)               (None, 176, 1536)    591360      ['layer_normalization_12[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 176, 1536)   3072        ['dense_12[0][0]']
#  ormalization)
#
#  multi_head_self_attention_3 (M  (None, 176, 384)    1916928     ['layer_normalization_13[0][0]']
#  ultiHeadSelfAttention)
#
#  dropout_10 (Dropout)           (None, 176, 384)     0           ['multi_head_self_attention_3[0][
#                                                                  0]']
#
#  add_6 (Add)                    (None, 176, 384)     0           ['add_5[0][0]',
#                                                                   'dropout_10[0][0]']
#
#  layer_normalization_14 (LayerN  (None, 176, 384)    768         ['add_6[0][0]']
#  ormalization)
#
#  4_expand_conv (Dense)          (None, 176, 1536)    591360      ['layer_normalization_14[0][0]']
#
#  4_dwconv (CausalDWConv1D)      (None, 176, 1536)    26112       ['4_expand_conv[0][0]']
#
#  4_bn (BatchNormalization)      (None, 176, 1536)    6144        ['4_dwconv[0][0]']
#
#  eca_3 (ECA)                    (None, 176, 1536)    5           ['4_bn[0][0]']
#
#  4_project_conv (Dense)         (None, 176, 384)     590208      ['eca_3[0][0]']
#
#  4_drop (Dropout)               (None, 176, 384)     0           ['4_project_conv[0][0]']
#
#  4_add (Add)                    (None, 176, 384)     0           ['4_drop[0][0]',
#                                                                   'layer_normalization_14[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 176, 384)    768         ['4_add[0][0]']
#  ormalization)
#
#  dense_15 (Dense)               (None, 176, 384)     147840      ['layer_normalization_15[0][0]']
#
#  dropout_11 (Dropout)           (None, 176, 384)     0           ['dense_15[0][0]']
#
#  add_7 (Add)                    (None, 176, 384)     0           ['dropout_11[0][0]',
#                                                                   'add_5[0][0]']
#
#  layer_normalization_16 (LayerN  (None, 176, 384)    768         ['add_7[0][0]']
#  ormalization)
#
#  dense_16 (Dense)               (None, 176, 1536)    591360      ['layer_normalization_16[0][0]']
#
#  layer_normalization_17 (LayerN  (None, 176, 1536)   3072        ['dense_16[0][0]']
#  ormalization)
#
#  multi_head_self_attention_4 (M  (None, 176, 384)    1916928     ['layer_normalization_17[0][0]']
#  ultiHeadSelfAttention)
#
#  dropout_13 (Dropout)           (None, 176, 384)     0           ['multi_head_self_attention_4[0][
#                                                                  0]']
#
#  add_8 (Add)                    (None, 176, 384)     0           ['add_7[0][0]',
#                                                                   'dropout_13[0][0]']
#
#  layer_normalization_18 (LayerN  (None, 176, 384)    768         ['add_8[0][0]']
#  ormalization)
#
#  5_expand_conv (Dense)          (None, 176, 1536)    591360      ['layer_normalization_18[0][0]']
#
#  5_dwconv (CausalDWConv1D)      (None, 176, 1536)    26112       ['5_expand_conv[0][0]']
#
#  5_bn (BatchNormalization)      (None, 176, 1536)    6144        ['5_dwconv[0][0]']
#
#  eca_4 (ECA)                    (None, 176, 1536)    5           ['5_bn[0][0]']
#
#  5_project_conv (Dense)         (None, 176, 384)     590208      ['eca_4[0][0]']
#
#  5_drop (Dropout)               (None, 176, 384)     0           ['5_project_conv[0][0]']
#
#  5_add (Add)                    (None, 176, 384)     0           ['5_drop[0][0]',
#                                                                   'layer_normalization_18[0][0]']
#
#  layer_normalization_19 (LayerN  (None, 176, 384)    768         ['5_add[0][0]']
#  ormalization)
#
#  dense_19 (Dense)               (None, 176, 384)     147840      ['layer_normalization_19[0][0]']
#
#  dropout_14 (Dropout)           (None, 176, 384)     0           ['dense_19[0][0]']
#
#  add_9 (Add)                    (None, 176, 384)     0           ['dropout_14[0][0]',
#                                                                   'add_7[0][0]']
#
#  layer_normalization_20 (LayerN  (None, 176, 384)    768         ['add_9[0][0]']
#  ormalization)
#
#  dense_20 (Dense)               (None, 176, 1536)    591360      ['layer_normalization_20[0][0]']
#
#  layer_normalization_21 (LayerN  (None, 176, 1536)   3072        ['dense_20[0][0]']
#  ormalization)
#
#  multi_head_self_attention_5 (M  (None, 176, 384)    1916928     ['layer_normalization_21[0][0]']
#  ultiHeadSelfAttention)
#
#  dropout_16 (Dropout)           (None, 176, 384)     0           ['multi_head_self_attention_5[0][
#                                                                  0]']
#
#  add_10 (Add)                   (None, 176, 384)     0           ['add_9[0][0]',
#                                                                   'dropout_16[0][0]']
#
#  layer_normalization_22 (LayerN  (None, 176, 384)    768         ['add_10[0][0]']
#  ormalization)
#
#  6_expand_conv (Dense)          (None, 176, 1536)    591360      ['layer_normalization_22[0][0]']
#
#  6_dwconv (CausalDWConv1D)      (None, 176, 1536)    26112       ['6_expand_conv[0][0]']
#
#  6_bn (BatchNormalization)      (None, 176, 1536)    6144        ['6_dwconv[0][0]']
#
#  eca_5 (ECA)                    (None, 176, 1536)    5           ['6_bn[0][0]']
#
#  6_project_conv (Dense)         (None, 176, 384)     590208      ['eca_5[0][0]']
#
#  6_drop (Dropout)               (None, 176, 384)     0           ['6_project_conv[0][0]']
#
#  6_add (Add)                    (None, 176, 384)     0           ['6_drop[0][0]',
#                                                                   'layer_normalization_22[0][0]']
#
#  layer_normalization_23 (LayerN  (None, 176, 384)    768         ['6_add[0][0]']
#  ormalization)
#
#  dense_23 (Dense)               (None, 176, 384)     147840      ['layer_normalization_23[0][0]']
#
#  dropout_17 (Dropout)           (None, 176, 384)     0           ['dense_23[0][0]']
#
#  add_11 (Add)                   (None, 176, 384)     0           ['dropout_17[0][0]',
#                                                                   'add_9[0][0]']
#
#  top_conv (Dense)               (None, 176, 768)     295680      ['add_11[0][0]']
#
#  dropout_18 (Dropout)           (None, 176, 768)     0           ['top_conv[0][0]']
#
#  classifier (Dense)             (None, 176, 60)      46140       ['dropout_18[0][0]']
#
# ==================================================================================================
# Total params: 23,701,338
# Trainable params: 23,682,138
# Non-trainable params: 19,200
# __________________________________________________________________________________________________

# %%
def num_to_char_fn(y):
    return [num_to_char.get(x, "") for x in y]

@tf.function()
def decode_phrase(pred):
    x = tf.argmax(pred, axis=1)
    diff = tf.not_equal(x[:-1], x[1:])
    adjacent_indices = tf.where(diff)[:, 0]
    x = tf.gather(x, adjacent_indices)
    mask = x != pad_token_idx
    x = tf.boolean_mask(x, mask, axis=0)
    return x

# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    output_text = []
    for result in pred:
        result = "".join(num_to_char_fn(decode_phrase(result).numpy()))
        output_text.append(result)
    return output_text

# %%
# A callback class to output a few transcriptions during training
class CallbackEval(tf.keras.callbacks.Callback):
    """Displays a batch of outputs after every epoch."""

    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def on_epoch_end(self, epoch: int, logs=None):
        model.save_weights("model.h5")
        predictions = []
        targets = []
        for batch in self.dataset:
            X, y = batch
            batch_predictions = model(X)
            batch_predictions = decode_batch_predictions(batch_predictions)
            predictions.extend(batch_predictions)
            for label in y:
                label = "".join(num_to_char_fn(label.numpy()))
                targets.append(label)
        print("-" * 100)
        # for i in np.random.randint(0, len(predictions), 2):
        for i in range(32):
            print(f"Target    : {targets[i]}")
            print(f"Prediction: {predictions[i]}, len: {len(predictions[i])}")
            print("-" * 100)

# Callback function to check transcription on the val set.
validation_callback = CallbackEval(val_dataset.take(1))

# %%
N_EPOCHS = 2 if IS_INTERACTIVE else 15
N_WARMUP_EPOCHS = 0 if IS_INTERACTIVE else 5
LR_MAX = 4e-3
WD_RATIO = 0.05
WARMUP_METHOD = "exp"

# %%
def lrfn(current_step, num_warmup_steps, lr_max, num_cycles=0.50, num_training_steps=N_EPOCHS):
    
    if current_step < num_warmup_steps:
        if WARMUP_METHOD == 'log':
            return lr_max * 0.10 ** (num_warmup_steps - current_step)
        else:
            return lr_max * 2 ** -(num_warmup_steps - current_step)
    else:
        progress = float(current_step - num_warmup_steps) / float(max(1, num_training_steps - num_warmup_steps))

        return max(0.0, 0.5 * (1.0 + math.cos(math.pi * float(num_cycles) * 2.0 * progress))) * lr_max
    
def plot_lr_schedule(lr_schedule, epochs):
    fig = plt.figure(figsize=(20, 10))
    plt.plot([None] + lr_schedule + [None])
    # X Labels
    x = np.arange(1, epochs + 1)
    x_axis_labels = [i if epochs <= 40 or i % 5 == 0 or i == 1 else None for i in range(1, epochs + 1)]
    plt.xlim([1, epochs])
    plt.xticks(x, x_axis_labels) # set tick step to 1 and let x axis start at 1
    
    # Increase y-limit for better readability
    plt.ylim([0, max(lr_schedule) * 1.1])
    
    # Title
    schedule_info = f'start: {lr_schedule[0]:.1E}, max: {max(lr_schedule):.1E}, final: {lr_schedule[-1]:.1E}'
    plt.title(f'Step Learning Rate Schedule, {schedule_info}', size=18, pad=12)
    
    # Plot Learning Rates
    for x, val in enumerate(lr_schedule):
        if epochs <= 40 or x % 5 == 0 or x is epochs - 1:
            if x < len(lr_schedule) - 1:
                if lr_schedule[x - 1] < val:
                    ha = 'right'
                else:
                    ha = 'left'
            elif x == 0:
                ha = 'right'
            else:
                ha = 'left'
            plt.plot(x + 1, val, 'o', color='black');
            offset_y = (max(lr_schedule) - min(lr_schedule)) * 0.02
            plt.annotate(f'{val:.1E}', xy=(x + 1, val + offset_y), size=12, ha=ha)
    
    plt.xlabel('Epoch', size=16, labelpad=5)
    plt.ylabel('Learning Rate', size=16, labelpad=5)
    plt.grid()
    plt.show()

# Learning rate for encoder
LR_SCHEDULE = [lrfn(step, num_warmup_steps=N_WARMUP_EPOCHS, lr_max=LR_MAX, num_cycles=0.50) for step in range(N_EPOCHS)]
# Plot Learning Rate Schedule
plot_lr_schedule(LR_SCHEDULE, epochs=N_EPOCHS)
# Learning Rate Callback
lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda step: LR_SCHEDULE[step], verbose=0)

# Custom callback to update weight decay with learning rate
class WeightDecayCallback(tf.keras.callbacks.Callback):
    def __init__(self, wd_ratio=WD_RATIO):
        self.step_counter = 0
        self.wd_ratio = wd_ratio
    
    def on_epoch_begin(self, epoch, logs=None):
        model.optimizer.weight_decay = model.optimizer.learning_rate * self.wd_ratio
        print(f'learning rate: {model.optimizer.learning_rate.numpy():.2e}, weight decay: {model.optimizer.weight_decay.numpy():.2e}')

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=N_EPOCHS,
    callbacks=[
        validation_callback,
        lr_callback,
        WeightDecayCallback(),
    ]
)
# Out:
# learning rate: 1.25e-04, weight decay: 6.25e-06
# Epoch 1/15
#     492/Unknown - 690s 1s/step - loss: 87.4937----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 698s 1s/step - loss: 87.4937 - val_loss: 77.4347 - lr: 1.2500e-04
# learning rate: 2.50e-04, weight decay: 1.25e-05
# Epoch 2/15
# 492/492 [==============================] - ETA: 0s - loss: 61.9159----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 648s 1s/step - loss: 61.9159 - val_loss: 63.6470 - lr: 2.5000e-04
# learning rate: 5.00e-04, weight decay: 2.50e-05
# Epoch 3/15
# 492/492 [==============================] - ETA: 0s - loss: 50.9738----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 33erse, len: 6
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: ssrhhal, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 35ia lie, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: re, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 2ortheatrod, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: re, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: tps//ss/o, len: 9
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 3soe, len: 4
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 7, len: 1
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 1 brerr, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: i, len: 1
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: /arih/l, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: inecin/coe/, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 57083, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: ena, len: 3
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 04, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: icoo, len: 4
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: c, len: 1
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: anileive, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: rarr, len: 4
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 40, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: nesiv, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 54, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: teiep, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 8era, len: 4
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: iccrl, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: hhaco, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 647s 1s/step - loss: 50.9738 - val_loss: 39.8055 - lr: 5.0000e-04
# learning rate: 1.00e-03, weight decay: 5.00e-05
# Epoch 4/15
# 492/492 [==============================] - ETA: 0s - loss: 35.9333----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 3 cekouse, len: 9
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: salesuhaila, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 1383wiliam anier, len: 16
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: fa1ne, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: f2oortheaststrod, len: 16
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: w.fre.me, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: https://isi.is/uoka, len: 19
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 291t3stoleret, len: 13
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 176, len: 3
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 2710f7boreboulevr, len: 17
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: ericoero, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: /arpinape-fith/litle, len: 20
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: kine-cin/code/, len: 14
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +977487, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +51711-08-3, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: wld, len: 3
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: lenaowen, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +220-55-89-4, len: 12
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: kiicaro, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: r, len: 1
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 867haniledrive, len: 14
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 16w0twater, len: 10
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +45-9-07-887, len: 12
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 5634/eneseooriv, len: 15
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 54, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 18 cuttecridgeroap, len: 18
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: aaf, len: 3
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 9188 wtv8teraou, len: 15
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: jmimcfrl, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: hwhorsilutraed.com/, len: 19
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 111 eastuofthrad, len: 16
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 648s 1s/step - loss: 35.9333 - val_loss: 31.8981 - lr: 0.0010
# learning rate: 2.00e-03, weight decay: 1.00e-04
# Epoch 5/15
# 492/492 [==============================] - ETA: 0s - loss: 32.4403----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 33rekhorse, len: 10
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: saales/rhaila, len: 13
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 1383wiliawm lanier, len: 18
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 988 frnnlne, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 920utheast wstroad, len: 18
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: ww.freem.me.i, len: 13
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: htps://isi.is/hroka, len: 19
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 2391stlesret, len: 12
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 217, len: 3
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 271097 bioreboulevard, len: 21
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: erericoneroon, len: 13
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: /arpinaope-s-fith/litle, len: 23
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: kine-cin/code/, len: 14
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +4975487, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +51-711-08-63, len: 13
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: wldo-, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: lenaowen, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +220-57-89-04, len: 13
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: kaiicasro, len: 9
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 6867 hanvile drive, len: 18
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 60twaer, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +45-9-007-1877, len: 14
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 65634/enesseooriv, len: 17
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 54, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 18 cutter cridgereoad, len: 21
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: tamaf, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 91288 wst 28erasou, len: 18
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: jmimcfrlld, len: 10
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: hw.horsilua.ra.ed.com/, len: 22
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 1121 ast v6thrad, len: 16
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 648s 1s/step - loss: 32.4403 - val_loss: 29.9034 - lr: 0.0020
# learning rate: 4.00e-03, weight decay: 2.00e-04
# Epoch 6/15
# 492/492 [==============================] - ETA: 0s - loss: 58.5410----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 647s 1s/step - loss: 58.5410 - val_loss: 63.7820 - lr: 0.0040
# learning rate: 3.90e-03, weight decay: 1.95e-04
# Epoch 7/15
# 492/492 [==============================] - ETA: 0s - loss: 63.4818----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 648s 1s/step - loss: 63.4818 - val_loss: 64.2078 - lr: 0.0039
# learning rate: 3.62e-03, weight decay: 1.81e-04
# Epoch 8/15
# ...
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 563/enesi, len: 9
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 54, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 8riera, len: 6
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: af, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 486tco, len: 6
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: jmimfarlad, len: 10
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: hhosistad.com, len: 13
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 1athra, len: 6
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 649s 1s/step - loss: 43.8495 - val_loss: 39.6616 - lr: 8.2443e-04
# learning rate: 3.82e-04, weight decay: 1.91e-05
# Epoch 14/15
# 492/492 [==============================] - ETA: 0s - loss: 41.7676----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 3ekhore, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: siaalsphaya, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 83wiliamlanier, len: 14
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 98fnkne, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 792otheatww, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: .frenme, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: htps://ssiis/oka, len: 16
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 96smsr, len: 6
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 27194yorsbo0rlvr, len: 16
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: icrn, len: 4
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: /ariah-/.fih/litl, len: 17
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: ineincod/, len: 9
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +6-9--8226227, len: 13
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +51-7-8-63, len: 10
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: lenawen, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 2054-9-4, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: aticco, len: 6
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 86hanvyledrive, len: 14
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: owar, len: 4
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +45-9-00-87, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 65634/enesse/oi, len: 15
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 54, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 8orriera, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: f, len: 1
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 486tco, len: 6
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 6w, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: jjmimfrlad, len: 10
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: hw.hosilstad.com, len: 16
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 1atvha, len: 6
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 651s 1s/step - loss: 41.7676 - val_loss: 38.2050 - lr: 3.8197e-04
# learning rate: 9.79e-05, weight decay: 4.89e-06
# Epoch 15/15
# 492/492 [==============================] - ETA: 0s - loss: 40.7407----------------------------------------------------------------------------------------------------
# Target    : 3 creekhouse^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 3ekhore, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : scales/kuhaylah^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: siaalspuhaia, len: 12
# ----------------------------------------------------------------------------------------------------
# Target    : 1383 william lanier^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 383wiliamlanier, len: 15
# ----------------------------------------------------------------------------------------------------
# Target    : 988 franklin lane^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 98ftkne, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : 6920 northeast 661st road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 920otheastwstr, len: 14
# ----------------------------------------------------------------------------------------------------
# Target    : www.freem.ne.jp^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: .frenme, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : https://jsi.is/hukuoka^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: https//ssiis/uka, len: 16
# ----------------------------------------------------------------------------------------------------
# Target    : 239613 stolze street^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 963stmsr, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : 242-197-6202^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 271097 bayshore boulevard^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 271094yorsb0rlvr, len: 16
# ----------------------------------------------------------------------------------------------------
# Target    : federico pearson^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: icron, len: 5
# ----------------------------------------------------------------------------------------------------
# Target    : /carpina/hope_&_faith/litle^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: /ariahme-/.fih/litl, len: 19
# ----------------------------------------------------------------------------------------------------
# Target    : dine-in/code/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: ineincode/, len: 10
# ----------------------------------------------------------------------------------------------------
# Target    : +264-97-568-217-145^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 6-9--822275, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : +51-2721-208-63^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +517-8-3, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : wildberries_ru^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: wa, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : leona owens^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: enamwen, len: 7
# ----------------------------------------------------------------------------------------------------
# Target    : +220-557-859-04^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 2054-9-4, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : kati castro^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: katiccro, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : 5566 hellertown road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: , len: 0
# ----------------------------------------------------------------------------------------------------
# Target    : 6867 granville drive^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 86hanvyledrive, len: 14
# ----------------------------------------------------------------------------------------------------
# Target    : 1600 fire water^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: owar, len: 4
# ----------------------------------------------------------------------------------------------------
# Target    : +45-39-007-1887^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: +45-9-00-87, len: 11
# ----------------------------------------------------------------------------------------------------
# Target    : 65634/tennessee%20river^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 65634/enesse/oi, len: 15
# ----------------------------------------------------------------------------------------------------
# Target    : 596-033-4046^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 54, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 18 cutter ridge road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 82oriera, len: 8
# ----------------------------------------------------------------------------------------------------
# Target    : tampa fl^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: af, len: 2
# ----------------------------------------------------------------------------------------------------
# Target    : 492288 west 28th terrace south^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 486tco, len: 6
# ----------------------------------------------------------------------------------------------------
# Target    : 166 water power^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 6, len: 1
# ----------------------------------------------------------------------------------------------------
# Target    : jami mcfarland^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: jmimfarlad, len: 10
# ----------------------------------------------------------------------------------------------------
# Target    : www.horseillustrated.com/^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: hwhosilsataec.com, len: 17
# ----------------------------------------------------------------------------------------------------
# Target    : 1121 east 2609th road^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prediction: 21atvfhra, len: 9
# ----------------------------------------------------------------------------------------------------
# 492/492 [==============================] - 650s 1s/step - loss: 40.7407 - val_loss: 37.5223 - lr: 9.7887e-05

# %%
class TFLiteModel(tf.Module):
    def __init__(self, model):
        super(TFLiteModel, self).__init__()
        self.model = model
    
    @tf.function(input_signature=[tf.TensorSpec(shape=[None, len(SEL_COLS)], dtype=tf.float32, name='inputs')])
    def __call__(self, inputs, training=False):
        # Preprocess Data
        x = tf.cast(inputs, tf.float32)
        x = x[None]
        x = tf.cond(tf.shape(x)[1] == 0, lambda: tf.zeros((1, 1, len(SEL_COLS))), lambda: tf.identity(x))
        x = x[0]
        x = pre_process00(x)
        x = pre_process1(*x)
        x = tf.reshape(x, INPUT_SHAPE)
        x = x[None]
        x = self.model(x, training=False)
        x = x[0]
        x = decode_phrase(x)
        # POST PROCESS. IF PRED LESS THAN 3, USE CONSTANT PREDICTION FROM
        # https://www.kaggle.com/code/anokas/static-greedy-baseline-0-157-lb
        x = tf.cond(tf.shape(x)[0] < 3, lambda: tf.constant(
            [17, 0, 32, 12, 36, 0, 12, 32, 49, 46, 36], tf.int64), lambda: tf.identity(x))
        x = tf.one_hot(x, 59)
        return {'outputs': x}

tflitemodel_base = TFLiteModel(model)
tflitemodel_base(frames)["outputs"].shape
# Out:
# TensorShape([7, 59])

# %%
keras_model_converter = tf.lite.TFLiteConverter.from_keras_model(tflitemodel_base)
keras_model_converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS]#, tf.lite.OpsSet.SELECT_TF_OPS]
keras_model_converter.optimizations = [tf.lite.Optimize.DEFAULT]
keras_model_converter.target_spec.supported_types = [tf.float16]
tflite_model = keras_model_converter.convert()
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
    
with open('inference_args.json', "w") as f:
    json.dump({"selected_columns" : SEL_COLS}, f)
    
# !zip submission.zip  './model.tflite' './inference_args.json'
# Out:
#   adding: model.tflite (deflated 8%)
#   adding: inference_args.json (deflated 83%)

# %%
with open ("inference_args.json", "r") as f:
    SEL_COLS = json.load(f)["selected_columns"]
    
def load_relevant_data_subset(pq_path):
    return pd.read_parquet(pq_path, columns=SEL_COLS)

def create_data_gen(file_ids, y_mul=1):
    def gen():
        for file_id in file_ids:
            pqfile = f"{inpdir}/{file_id}.parquet"
            seq_refs = df.loc[df.file_id == file_id]
            seqs = load_relevant_data_subset(pqfile)

            for seq_id in seq_refs.sequence_id:
                x = seqs.iloc[seqs.index == seq_id].to_numpy()
                y = str(df.loc[df.sequence_id == seq_id].phrase.iloc[0])
                
                r_nonan = np.sum(np.sum(np.isnan(x[:, RHAND_IDX_X]), axis = 1) == 0)
                l_nonan = np.sum(np.sum(np.isnan(x[:, LHAND_IDX_X]), axis = 1) == 0)
                no_nan = max(r_nonan, l_nonan)
                
                if y_mul*len(y)<no_nan:
                    yield x, y
    return gen

pqfiles = df.file_id.unique()
val_len = int(0.05 * len(pqfiles))

test_dataset = tf.data.Dataset.from_generator(create_data_gen(pqfiles[:val_len], 0),
    output_signature=(tf.TensorSpec(shape=(None, len(SEL_COLS)), dtype=tf.float32), tf.TensorSpec(shape=(), dtype=tf.string))
).prefetch(buffer_size=2000)

# %%
interpreter = tf.lite.Interpreter("model.tflite")

REQUIRED_SIGNATURE = "serving_default"
REQUIRED_OUTPUT = "outputs"

with open ("/kaggle/input/asl-fingerspelling/character_to_prediction_index.json", "r") as f:
    character_map = json.load(f)
rev_character_map = {j:i for i,j in character_map.items()}

prediction_fn = interpreter.get_signature_runner(REQUIRED_SIGNATURE)

for frame, target in test_dataset.skip(100).take(10):
    output = prediction_fn(inputs=frame)
    prediction_str = "".join([rev_character_map.get(s, "") for s in np.argmax(output[REQUIRED_OUTPUT], axis=1)])
    target = target.numpy().decode("utf-8")
    print("pred =", prediction_str, "; target =", target)
# Out:
# pred = 2 a-e -aroe ; target = 4874 sairley
# pred = +55-2 ; target = 752-573-2075
# pred = tbiylarson ; target = toby larson
# pred = +89-4-4-66 ; target = +878-34-43-656
# pred = +2-499-8-9528 ; target = +49-81-95228
# pred = 3830390h ; target = 3830 pn 3906th
# pred = 3445a ; target = +31-103-4764-61-76950
# pred = .lmncoij ; target = www.lemon.co.jp
# pred = 5 nawadrive ; target = 7575 onawa drive
# pred = 5-896 ; target = 841-199-8196

# %%
# %%timeit -n 10
output = prediction_fn(inputs=frame)
# Out:
# 262 ms ± 2.36 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
from Levenshtein import distance

scores = []

for i, (frame, target) in tqdm(enumerate(test_dataset.take(1000))):
    output = prediction_fn(inputs=frame)
    prediction_str = "".join([rev_character_map.get(s, "") for s in np.argmax(output[REQUIRED_OUTPUT], axis=1)])
    target = target.numpy().decode("utf-8")
    score = (len(target) - distance(prediction_str, target)) / len(target)
    scores.append(score)
    if i % 50 == 0:
        print(np.sum(scores) / len(scores))
    
scores = np.array(scores)
print(np.sum(scores) / len(scores))
# Out:
# 1it [00:00,  1.36it/s]
# 0.25
# 51it [00:14,  3.74it/s]
# 0.3678536962115763
# 101it [00:28,  3.81it/s]
# 0.339693494308067
# 151it [00:41,  3.79it/s]
# 0.34803639455158625
# 201it [00:55,  3.75it/s]
# 0.33794781791095185
# 251it [01:08,  3.77it/s]
# 0.33606417337221134
# 301it [01:21,  3.86it/s]
# 0.3333292182218769
# 351it [01:34,  3.81it/s]
# 0.3306115047661056
# 401it [01:47,  3.84it/s]
# 0.3305341610794517
# 451it [02:00,  3.86it/s]
# 0.33082555799714586
# 501it [02:13,  3.78it/s]
# 0.337615697524212
# 551it [02:27,  3.65it/s]
# 0.3358102597256906
# 601it [02:40,  3.74it/s]
# 0.3390022861978318
# 651it [02:54,  3.70it/s]
# 0.3409685622207489
# 701it [03:08,  3.88it/s]
# 0.3387148400863721
# 751it [03:21,  3.80it/s]
# 0.3408598945620391
# 801it [03:34,  3.83it/s]
# 0.340943684086468
# 851it [03:48,  3.63it/s]
# 0.34137963781218017
# 901it [04:01,  3.65it/s]
# 0.3402523840692771
# 951it [04:15,  3.81it/s]
# 0.3404322131312953
# 1000it [04:28,  3.73it/s]
# 0.3380787895628956
